# %% [markdown]
# # URL
#
# https://stackoverflow.com/questions/28931224/adding-value-labels-on-a-matplotlib-bar-chart/28931750#28931750

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Bring some raw data in the list
frequencies = [6, -16, 75, 160, 244, 260, 145, 73, 16, 4, 1]

# %%
# Converted into pandas series since plot() doesn't work with list
freq_series = pd.Series(frequencies)
freq_series
# Out:
# 0       6
# 1     -16
# 2      75
# 3     160
# 4     244
# 5     260
# 6     145
# 7      73
# 8      16
# 9       4
# 10      1
# dtype: int64

# %%
# Labels for X as Groups
x_labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']

# %%
# Plotting it simply to check
freq_series.plot(kind='bar')

# %% [markdown]
# # Vertical Bar

# %%
# Plotting the figure with labels
plt.figure(figsize=(14,8))

ax = freq_series.plot(kind='bar')    # this will be axis

ax.set_title('Plotting the chart')
ax.set_xlabel('Group')
ax.set_ylabel('Frequency')
ax.set_xticklabels(x_labels)

rects = ax.patches


# For each bar : place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2
    
    # Number of pints between bar and label : as per our choice
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'
    
    # If value of bar is negative : Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'
        
    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(y_value)
    
    # Create annotation
    plt.annotate(
        label,                           # Use 'label' as label
        (x_value, y_value),              # Place label at the end of the bar
        xytext = (0,space),              # Vertically shiift label by space
        textcoords = 'offset points',    # Interpret 'xytext' as offset in points
        ha = 'center',                   # Horizontally center labels
        va = va)                         # Vertically align label differently for 
                                         # positive and negative values

# %% [markdown]
# # Horizontal Bar

# %%
# Labels for Y as Groups
y_labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']

# %%
# Plotting the figure with labels
plt.figure(figsize=(12,8))

ax = freq_series.plot(kind='barh')    # this will be axis

ax.set_title('Plotting the chart')
ax.set_xlabel('Group')
ax.set_ylabel('Frequency')
ax.set_yticklabels(y_labels)
ax.set_xlim(-40, 300) # expand xlim to make labels easier to read 

rects = ax.patches


# For each bar : place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2
    
    # Number of pints between bar and label : as per our choice
    space = 5
    # Horizontal alignment for positive values
    ha = 'left'
    
    # If value of bar is negative : Place label to right bar
    if x_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        ha = 'right'
        
    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(x_value)
    
    # Create annotation
    plt.annotate(
        label,                           # Use 'label' as label
        (x_value, y_value),              # Place label at the end of the bar
        xytext = (0,space),              # Horizontally shift label by space
        textcoords = 'offset points',    # Interpret 'xytext' as offset in points
        va = 'center',                   # Horizontally center labels
        ha = ha)                         # Horizontally align label differently for 
                                         # positive and negative values
